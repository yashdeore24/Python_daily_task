# %% [markdown]
# # Here are 20 Questions on Nested Conditions (if, if-else, if-elif-else)

# %% [markdown]
# ### 1. Take a number as input. If the number is positive, check whether it is even or odd and print the result.

# %%
number = int(input("Enter the number:"))

if number > 0:
    if number % 2 == 0:
        print("Even")
    else:
        print("Odd")
else:
    print("Number is zeor or negative")
# Out:
# Enter the number: 0
# Number is zeor or negative

# %% [markdown]
# ### 2. Take age as input. If age is greater than or equal to 18, check if the person is a
# ### senior citizen (age >= 60) or adult.

# %%
Age = int(input("Enter the age:"))
if Age >= 18:
    if Age >= 60:
        print("Senior citizen")
    else:
        print("Adult")
else:
    print("child")
# Out:
# Enter the age: 66
# Senior citizen

# %%
### 3. Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.
char = input("Enter any character:")

if char.isalpha():
    if char.isupper():
        print("Uppercase")
    else:
        print("Lowercase")
else:
    print("please enter alphabet")
# Out:
# Enter any character: 5
# Character is not alphadet

# %%
### 4. Take three numbers as input and print the largest number using nested if statements (without using max())

a = int(input())
b = int(input())
c = int(input())

if a > b:
    if a > c:
        print(f"{a} is gratter than {b} and {c}")
    else: 
        print(f"{c} is gratter than {b} and {a}")
else :
    if b > a:
        print(f"{b} is gratter than {c} and {a}")
    else:
         print(f"{c} is gratter than {b} and {a}")
# Out:
#  2
#  5
#  1
# 5 is gratter than 1 and 2

# %% [markdown]
# ### 5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to print "Pass with Distinction".

# %%
marks = int(input("Ente student marks:"))

if marks >= 40:

    if marks >= 75:
        print("pass with Distinction")
    else:
        print("pass")
else:
    print("Faid")
# Out:
# Ente student marks: 66
# pass

# %% [markdown]
# ### 6.Take a number. If it is divisible by 2, check if it is also divisible by 4.

# %%
num = int(input("Enter any number:"))

if num % 2 == 0:
    if num % 4 == 0:
        print("number is divisible by both")
    else:
        print("Number only divisible by 2")

else:
    print("Number is not divisible by both")
# Out:
# Enter any number: 5
# Number is not divisible by both

# %% [markdown]
# ### 7. Take username and password. If username is "admin", then check if the password is correct.

# %%
USER_NAME ="admin"
PASSWORD = 1234

user_name = input("Enter the username:")
password = int(input("Enter the password:"))

if user_name == USER_NAME:
    if password == PASSWORD:
        print("Login successful")
    else:
        print("Password is not match")
else:
    print("user name is not match")
# Out:
# Enter the username: admin
# Enter the password: 1234
# Login successful

# %% [markdown]
# ### 8. Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.

# %%
s1 = float(input("Enter the first side:"))
s2 = float(input("Enter the secound side:"))
s3 = float(input("Enter the third side:"))

if s1 + s2 > s3 and s2 + s3 > s1 and s3 + s1 > s2:
    if s1 == s2 == s3:
        print("Equilateral triangle")
    elif s1 == s2 or s2 == s3 or s3 == s1:
        print("isosceles triangle")
    elif s1 != s2 != s3:
        print("Scalene triangle")
else:
    print("invalid triangle:")
# Out:
# Enter the first side: 2
# Enter the secound side: 2
# Enter the third side: 4
# invalid triangle:

# %% [markdown]
# ### 9. Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".

# %%
salary = int(input("Enter the salary:"))
exp = int(input("Enter the Experience:"))

if salary > 50000:
    if exp < 10:
        print("Manager")
    else:
        print("Senior manager")

else:
    print("salary is less than 50000")
# Out:
# Enter the salary: 440000
# Enter the Experience: 11
# Senior manager

# %% [markdown]
# ### 10.Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit, print "Digit". Else print "Special Character".

# %%
char = input("Enter any character:")
char = char.lower()
Len = len(char)
if Len == 1:
    if char == 'a' or char == 'i' or char == 'e' or char == 'o' or char == 'u':
        print("It is a Vowel")
    elif char.isdigit():
        print("It is a digit")
    else:
        print("It is a consonant")
        
else:
    print("it is not letter")
# Out:
# Enter any character: j
# It is a consonant

# %%
### 11.Take a year as input. Check if it is a leap year using nested conditions.
year = int(input("Enter the year:"))

if year % 4 == 0 and year % 100 == 0 :
    if year % 400 == 0:
        print("Leap year:")
    else:
        print("Not leap year:")
else:
    print("not leap year:")

# %% [markdown]
# ### 12.Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm", else "Cold" using nested if.

# %%
tem = float(input("Enter the temperature:"))

if tem > 30:
    if tem >= 20 and tem <= 30:
        print("Hot")
    else:
        print("Warm")
else:
    print("cold")
# Out:
# Enter the temperature: 10
# cold

# %% [markdown]
# ### 13.Take three numbers. Check if all three are equal, or any two are equal using nested if.

# %%
n1 = int(input("Enter first number:"))
n2 = int(input("Enter second number:"))
n3 = int(input("Ente third numebr:"))

if n1 == n2 or n2 == n3 or n3 == n1:
    if n1 == n2 == n3 :
        print("all three are equal")
    else:
        print("two are equal")
else:
    print("Every number is different:")
# Out:
# Enter first number: 2
# Enter second number: 2
# Ente third numebr: 1
# two are equal

# %%
### 14.Take a number. If it is positive and even, print "Positive Even Number".
number = int(input("Enter any number:"))

if number > 0:
    if number % 2 == 0 :
        print(" number is positive and even")
    else:
        print("Numer is odd")
else:
    print("numbe may be zero or negative")
# Out:
# Enter any number: 2
#  number is positive and even

# %% [markdown]
# ### 15.Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.

# %%
s1 = int(input("Enter first subject marks:"))
s2 = int(input("Enter second subject marks:"))
s3 = int(input("Enter third subject marks:"))
s4 = int(input("Enter fourth subject marks:"))
s5 = int(input("Enter fifth subject marks:"))

avg = s1 + s2 + s3 +s4 + s5 / 5

if avg >= 60 :
    if s1 > 40 and s2 >40 and s3 > 40 and s4 > 40 and s5 > 40 :
        print("All subjects are above 40:")
    else:
        print("not all subjects are above 40:")
else:
    print("average is lessthan 60")
# Out:
# Enter first subject marks: 77
# Enter second subject marks: 88
# Enter third subject marks: 65
# Enter fourth subject marks: 56
# Enter fifth subject marks: 88
# All subjects are above 40:

# %% [markdown]
# ### 16.Take username, password, and age. If username and password are correct andage >= 18, print "Login Successful". Else if age < 18, print age restriction message.

# %%
USER_NAME = "yash@1234"
PASSWORD = 12345

user_name = input("Enter the username:")
password = int(input("Enter the password:"))
age = int(input("Enter the Age:"))


if user_name == USER_NAME and password == PASSWORD:
    if age >= 18:
        print("Login successful")
    else:
        print("Age restriction message")
else:
    print("user name and password not currect")
# Out:
# Enter the username: yash@123
# Enter the password: 12345
# Enter the Age: 22
# user name and password not currect

# %%
### 17.Take a number. Check if it is divisible by both 3 and 5 using nested if.

number = int(input("Enter any number:"))

if number % 3 == 0:
    if number % 5 == 0:
        print("Number is divisible by both")
    else:
        print("Number is only divisible by 3")
else:
    print("Number is not divisible by both")
# Out:
# Enter any number: 15
# Number is divisible by both

# %% [markdown]
# ### 18.Take three sides of a triangle. Check if valid, then check if it is a right-angled triangle using Pythagoras theorem.

# %%
a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))


if a + b > c and a + c > b and b + c > a:

    print("Valid triangle")

    
    sides = sorted([a, b, c])
    x, y, z = sides

    
    if x**2 + y**2 == z**2:
        print("It is a right-angled triangle.")
    else:
        print("It is not a right-angled triangle.")

else:
    print("Invalid triangle")
# Out:
# Enter first side:  1
# Enter second side:  2
# Enter third side:  4
# Invalid triangle

# %% [markdown]
# ### 19.Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent, Good, Average, etc.).

# %%
Input = input("Give the grade like A, B, C, D,F:")

Input =Input.upper()

if Input == 'A' or Input == 'B':
    print("Excellent")
elif Input == 'C' or Input == 'D':
    print("Good")
elif Input == 'D' or Input == 'F':
    print("Average")
else:
    print("Enter wrong grade")
# Out:
# Give the grade like A, B, C, D,F: a
# Excellent

# %% [markdown]
# ### 20.Take income. If income > 1000000, check tax slab. If income between 500000- 1000000, different slab. Else print "Low Income".

# %%
income = int(input("Enter your Encome:"))

if income > 1000000:
    print("High income")
    if income <= 2000000:
        print("Tax slad 30%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 30 / 100 *income} as Tax ")
    elif income <= 3000000:
        print("Tax slab 35%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 35/ 100 *income} as Tax ")

    elif income <= 4000000:
        print("Tax slab 40%:")
        print(f" income is ₹{income} and tax you want to pay ₹{ 40 / 100 *income} as Tax ")

elif income >= 500000:
        print("Middle income")
        if income <= 750000:
            print("Tax slab 20%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 20 / 100 *income} as Tax ")
        else:
            print("Tax slab 10%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 10 / 100 *income} as Tax ")
else:
    print("Tax slab 5%")
    print(f" income is ₹{income} and tax you want to pay ₹{5/ 100 *income} as Tax ")
# Out:
# Enter your Encome: 25000
# Tax slab 5%
#  income is ₹25000 and tax you want to pay ₹1250.0 as Tax

# %%
income = int(input("Enter your Encome:"))

if income > 1000000:
    print("High income")
    if income <= 2000000:
        print("Tax slad 30%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 30 / 100 *income} as Tax ")
    elif income <= 3000000:
        print("Tax slab 35%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 35/ 100 *income} as Tax ")

    elif income <= 4000000:
        print("Tax slab 40%:")
        print(f" income is ₹{income} and tax you want to pay ₹{ 40 / 100 *income} as Tax ")

elif income >= 500000:
        print("Middle income")
        if income <= 750000:
            print("Tax slab 20%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 20 / 100 *income} as Tax ")
        else:
            print("Tax slab 10%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 10 / 100 *income} as Tax ")
else:
    print("Tax slab 5%")
    print(f" income is ₹{income} and tax you want to pay ₹{5/ 100 *income} as Tax ")
# Out:
# Enter your Encome: 25000
# Tax slab 5%
#  income is ₹25000 and tax you want to pay ₹1250.0 as Tax

# %%
income = int(input("Enter your Encome:"))

if income > 1000000:
    print("High income")
    if income <= 2000000:
        print("Tax slad 30%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 30 / 100 *income} as Tax ")
    elif income <= 3000000:
        print("Tax slab 35%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 35/ 100 *income} as Tax ")

    elif income <= 4000000:
        print("Tax slab 40%:")
        print(f" income is ₹{income} and tax you want to pay ₹{ 40 / 100 *income} as Tax ")
    else:
        pirnt("Tax slab 45%")
        print(f" income is ₹{income} and tax you want to pay ₹{ 45 / 100 *income} as Tax ")

elif income >= 500000:
        print("Middle income")
        if income <= 750000:
            print("Tax slab 20%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 20 / 100 *income} as Tax ")
        else:
            print("Tax slab 10%")
            print(f" income is ₹{income} and tax you want to pay ₹{ 10 / 100 *income} as Tax ")
else:
    print("Tax slab 5%")
    print(f" income is ₹{income} and tax you want to pay ₹{5/ 100 *income} as Tax ")
# Out:
# Enter your Encome: 25000
# Tax slab 5%
#  income is ₹25000 and tax you want to pay ₹1250.0 as Tax

# %% [markdown]
# ### Extra More Question (Optional)

# %% [markdown]
# ### 1. (Hard) Take three sides of a triangle as input. First check if they can form a valid triangle (sum of any two sides > third side). If valid, then further check and print whether the triangle is Equilateral, Isosceles, or Scalene.

# %%
s1 = float(input("Enter the first side:"))
s2 = float(input("Enter the secound side:"))
s3 = float(input("Enter the third side:"))

if s1 + s2 > s3 and s2 + s3 > s1 and s3 + s1 > s2:
    if s1 == s2 == s3:
        print("Equilateral triangle")
    elif s1 == s2 or s2 == s3 or s3 == s1:
        print("isosceles triangle")
    elif s1 != s2 != s3:
        print("Scalene triangle")
else:
    print("invalid triangle:")

# %% [markdown]
# ### 2. (Hard) Take a student's marks in 5 subjects. Calculate the average. If average >=60, then check if all individual subjects are above 40. If yes, print "Pass with GoodPerformance", else print "Pass but Weak in some subjects". If average < 60, print "Fail".

# %%
s1 = int(input("Enter first subject marks:"))
s2 = int(input("Enter second subject marks:"))
s3 = int(input("Enter third subject marks:"))
s4 = int(input("Enter fourth subject marks:"))
s5 = int(input("Enter fifth subject marks:"))

avg = s1 + s2 + s3 +s4 + s5 / 5

if avg >= 60 :
    if s1 > 40 and s2 >40 and s3 > 40 and s4 > 40 and s5 > 40 :
        print("Pass with GoodPerformance")
    else:
        print("Pass but Weak in some subjects:")
else:
    print("fail")

# %% [markdown]
# ### 3.(Hard) Take username, password, and age as input.
# ###### • If username == "admin" and password == "python123" and age >= 18, print
# ######  "Login Successful".
# ###### • Else if age < 18, print "You are too young to login".
# ###### • Else if username is wrong, print "Invalid Username".
# ###### • Else print "Invalid Password".

# %%
USER_NAME = "admin"
PASSWORD = "python123"

user_name = input("Enter the username:")

if user_name == USER_NAME:
    password = input("Enter the password:")
    if password == PASSWORD:
        Age = int(input("Enter the age:"))
        if age >= 18:
            print("Login successful")
        else:
            print("You are too young to login")
        
    else:
        print("Invalid password")
else:
    print("Invalid username")

# %% [markdown]
# ### 4. (Hard) Take a number as input. Check if the number is positive. If positive, check if it is divisible by both 3 and 5. If yes, print "FizzBuzz". If only divisible by 3 print "Fizz", only by 5 print "Buzz". If negative, print "Negative Number".

# %%
number = int(input("Enter any number:"))

if number > 0:
    print("Number is positive")
   
    if number % 3 == 0 and number % 5 == 0:
        print("FizzBuzz")
    elif number % 5 == 0:
        if number % 3 == 0:
            print("Fizz")
        else:
            print("Buzz")
            
else:
    if number < 0:
        print("Negative number")
    else:
        print("number is Zero")
# Out:
# Enter any number: 10
# Number is positive
# Buzz

# %% [markdown]
# ### (Hard) Take three numbers. First check if all three are equal. If not, check which one is the largest. Also check if the largest number is even or odd and print all information accordingly.

# %%
n1 = int(input("Enter first Number:"))
n2 = int(input("Enter second Number:"))
n3 = int(input("Enter third Number:"))

if n1 == n2 == n3 :
    print("Number are equal")
else:
    if n1 >= n2:
        if n1 >= n3:
            
            print(f"{n1} is gratter")
            if n1 % 2 == 0:
                print(f"{n1} is even number")
            else:
                print(f"{n1} is odd number")
        else:
            
            print(f"{n3} is gratter")
            if n3 % 2 == 0:
                print(f"{n3} is even number")
            else:
                print(f"{n3} is odd number")
    else:
        if n2 >= n3:
            
            print(f"{n2} is gratter")
            if n2 % 2 == 0:
                print(f"{n2} is even number")
            else:
                print(f"{n2} is odd number")
        else:
          
            print(f"{n3} is gratter")
            if n3 % 2 == 0:
                print(f"{n1} is even number")
            else:
                print(f"{n1} is odd number")
# Out:
# Enter first Number: 1
# Enter second Number: 7
# Enter third Number: 5
# 7 is gratter
# 7 is odd number

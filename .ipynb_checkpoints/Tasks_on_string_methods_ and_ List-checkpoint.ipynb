# %% [markdown]
# # 1.Task

# %%
## 1. (Easy) Take a string from user and replace all spaces with underscore _ using replace() method.

string = input("Enter any string:")

string = string.replace(" " ,"_")
print(string)
# Out:
# Enter any string: yash bhalchandra deore
# yash_bhalchandra_deore

# %% [markdown]
# # 2.Task

# %%
# (Easy) Take any string and remove leading and trailing spaces using strip().

sting = input("Enter any string:")

print(sting.strip())
# Out:
# Enter any string:    yash
# yash

# %% [markdown]
# # 3.Task

# %%
#  (Easy) Take a sentence and check whether it starts with "Hello" using startswith().

string = input("Enter any string:")

print("yes it is start with 'Hello'"* ( string.startswith("Hello") ) or " not startwith Hellow")
# Out:
# Enter any string: yash
#  not startwith Hellow

# %% [markdown]
# # 4.Task

# %%
# 4. (Easy) Take a string and check if it ends with ".com" using endswith().

string = input("Enter any string:")

print("Yes it is ends with .com " * ( string.endswith(".com") ) or "not endswith .com")
# Out:
# Enter any string: deoreyash907@gmail.com
# Yes it is ends with .com

# %% [markdown]
# # 5.Task

# %%
# 5. (Easy) Take a comma-separated string like "apple,banana,mango" and split itusing split().

string = input("Enter any string:")

print(string.split(","))
# Out:
# Enter any string: apple,banana,mango
# ['apple', 'banana', 'mango']

# %% [markdown]
# # 6.Task

# %%
# 6. (Easy) Create a list of 5 fruits and join them using space " " with join().

list = ["apple","mango","banana","papaya","charry"]

print(" ".join(list))
# Out:
# apple mango banana papaya charry

# %% [markdown]
# # 7.task

# %%
# 7. (Easy) Create a list: [" Python ", " is ", " awesome "]. Strip each word and join them.
list =  [" Python ", " is ", " awesome "]

list[0] = list[0].strip()
list[1] = list[1].strip()
list[2] = list[2].strip()

list = "".join(list)
print(list)

print(list)
# Out:
# Pythonisawesome
# Pythonisawesome

# %% [markdown]
# # 8.Task

# %%
# 8. (Medium) Take a full name (e.g. "Rahul Kumar Sharma") and print only first and last name using split().

# %%
string = input("Enter any string:")

string = string.split()

print("First name :",string[0])
print("last name :",string[2])
# Out:
# Enter any string: yash Bhalchandra deore
# First name : yash
# last name : deore

# %% [markdown]
# # 9.task

# %%
# 9. (Medium) Take a sentence from user, split it into words, and print the total number of words
string = input("Enter any string:")

string = string.split(" ")
print(string)
print(len(string))
# Out:
# Enter any string: yash Bhalchandra Deore
# ['yash', 'Bhalchandra', 'Deore']
# 3

# %% [markdown]
# # 10.Task

# %%
# 10. (Medium) Take an email address and check if it ends with "@gmail.com" using endswith().

string = "email@gmail.com"

print(string.endswith("@gmail.com"))
# Out:
# True

# %% [markdown]
# # 11. Task

# %%
# 11. (Medium) Take a string "Hello World Python" . Replace "World" with "Everyone" and then split the result.

string = "Hello World Python"

string = string.replace("World","Everyone")

print(string.split(" "))
# Out:
# ['Hello', 'Everyone', 'Python']

# %% [markdown]
# # 12. Task

# %%
# 12. (Medium) Create a list of 5 city names from user input. Join them with new line"\n" and print.
city1 = input("Enter city 1: ")
city2 = input("Enter city 2: ")
city3 = input("Enter city 3: ")
city4 = input("Enter city 4: ")
city5 = input("Enter city 5: ")

cities = [city1, city2, city3, city4, city5]

result = "\n".join(cities)

print(result)

# %% [markdown]
# # 13.Task

# %%
# 13. (Medium) Take a string " hello world ". Strip it, convert to title case, and check if it starts with "Hello

string = " hello world "

string=string.strip()
print(string)
string = string.title()
print(string)

print(string.startswith("Hello"))
# Out:
# hello world
# Hello World
# True

# %% [markdown]
# # 14.Task

# %%
# 14. (Medium) Take a sentence and replace the word "bad" with "good" after splitting and joining.
string = " it is so bad "

string = string.replace("bad","good")

string = string.split()

print("_".join(string))
# Out:
# it_is_so_good

# %% [markdown]
# # 15.Task

# %%
# 15. (Medium) Take a list ["10", "20", "30", "40"] and join them with "-" using join().

list = ["10", "20", "30", "40"]

print("-".join(list))
# Out:
# 10-20-30-40

# %% [markdown]
# # 16. task

# %%
# 16. (Hard) Take a sentence. Split into words, remove all words that start with vowel (a,e,i,o,u), then join remaining words.

string = input("Enter any sentence:")

string = string.split()
print(string)

# %% [markdown]
# # 17. Task

# %%
# 17. (Hard) Take a string. Replace all spaces with -, then split by -, and print only words with length > 4.

string = input("Enter the string :")

string = string.replace(" ","-")
print(string)

string = string.split("-")

print(f"{string[0]}" * (len(string[0])> 4) or " ")
print(f"{string[1]}" * (len(string[1])> 4) or " ")
print(f"{string[2]}" * (len(string[2])> 4) or " ")
# Out:
# Enter the string : yash Bhalchandra Deore
# yash-Bhalchandra-Deore
# Bhalchandra

# %% [markdown]
# # 18.Task

# %%
# 18. (Hard) Create a list of student names. Join them with ", ". Then replace the first name with "New Student".

list = ["yash", "tanu", "Rohit"]
print(list)

list = ",".join(list)
print(list)

list = list.replace("yash","New student")

print(list)
# Out:
# ['yash', 'tanu', 'Rohit']
# yash,tanu,Rohit
# New student,tanu,Rohit

# %% [markdown]
# # 19. Task

# %%
# 19. (Hard) Take a paragraph. Split it into sentences (using .), strip each sentence, and join them with "\n- ".

paragraph = input("Enter any paragraph:")

paragraph = paragraph.split(".")
print(paragraph)

paragraph = "\n".join(paragraph)
print( paragraph)
# Out:
# Enter any paragraph: hi. i am yash
# ['hi', ' i am yash']
# hi
#  i am yash

# %% [markdown]
# # 20.Task

# %%
# 20. (Hard) Take a string. Use replace(), strip(), split(), and join() together to clean and reformat it as a proper sentence.

string = " i.am.yash.and.i.am.currently.live.in.ammerpet "

print("remove whitespaces:",string.strip())

print("split setence in words:",string.split("."))
string = string.split(".") 

print("Join all words with space:"," ".join(string))
string = " ".join(string)

string = string.replace("ammerpet","Hydrabad")

print("Replaced string:", string)
# Out:
# remove whitespaces: i.am.yash.and.i.am.currently.live.in.ammerpet
# split setence in words: [' i', 'am', 'yash', 'and', 'i', 'am', 'currently', 'live', 'in', 'ammerpet ']
# Join all words with space:  i am yash and i am currently live in ammerpet
# Replaced string:  i am yash and i am currently live in Hydrabad

# %% [markdown]
# # String Slicing Questions

# %% [markdown]
# ## 1. Take a string from user and print the first 5 characters.

# %%
string = input("Enter the string:")

print("First five characters:",string[ :5])
# Out:
# Enter the string: yash Deore
# First five characters: yash

# %% [markdown]
# ## 2. Take a string and print the last 4 characters using negative slicing.

# %%
string = input("Enter the string :")

print("last four character of string are:", string[-4:])
# Out:
# Enter the string : YASHDEORE
# last four character of string are: EORE

# %% [markdown]
# ## 3. Take a string and print characters from index 2 to 8 (excluding 8).

# %%
string = input("Enter the string:")

print("Characters for index 2 to 8 :", string[1 : 8])
# Out:
# Enter the string: yash bhalchandra deore
# Characters for index 2 to 8 : ash bha

# %% [markdown]
# ## 4. Take a string and print every 2nd character of the string.

# %% [markdown]
# string = input("Enter the string:")
#
# print("print very 2nd character of the string:", string[::2])

# %% [markdown]
# ## 5. Take a full name (e.g. "Sumit Kumar Sharma") and print only the first name and last name separately using slicing.

# %%
name = "Sumit kumar sharma"

print("First Name:",name[ : 5])
print("Last Name:",name[-6: ])
# Out:
# First Name: Sumit
# Last Name: sharma

# %% [markdown]
# # Case Conversion Questions

# %% [markdown]
# ## 6.Task

# %%
"""6. Take a string from user and print it in:
• Uppercase
• Lowercase
• Title Case
• Capitalized (only first letter capital)"""

string = input("Enter the string:")

print("Upper Case:",string.upper())
print("Lower Case:",string.lower())
print("Title Case:",string.title())
print("Capitalized:",string.capitalize())
# Out:
# Enter the string: Yash deore
# Upper Case: YASH DEORE
# Lower Case: yash deore
# Title Case: Yash Deore
# Capitalized: Yash deore

# %% [markdown]
# ## 7.task

# %% [markdown]
# ## Take a sentence and convert it to title case. Then print the original and converted version.

# %%
word = input("Enter the sentence:")

print("Coverterd version:",word.title())
print("original:",word)
# Out:
# Enter the sentence: yash deore
# Coverterd version: Yash Deore
# original: yash deore

# %% [markdown]
# ## 8.task

# %%
# Take a mixed case string and check if lower() and upper() ethods
# change the string permanently or not.
string = input("Enter any mixed string:")

print("Original string is :",string)

print("Lower string is:",string.lower())
print("Upper string is :", string.upper())

print("Original string is :",string)
# Out:
# Enter any mixed string: yasH DeORE
# Original string is : yasH DeORE
# Lower string is: yash deore
# Upper string is : YASH DEORE
# Original string is : yasH DeORE

# %% [markdown]
# # String Check Methods Questions

# %% [markdown]
# # 9.Task

# %%
# Take a string from user and check whether it contains only alphabets(isalpha()).

string = input("Enter the string:")

print(string.isalpha())
# Out:
# Enter the string: yash
# True

# %% [markdown]
# # 10.Task

# %%
# Take input from user and check if it is a digit only (isdigit()).

sting = intput("Enter the string :")

print(sting.isdigit()
# Out:
# Enter the string : 124
# True

# %% [markdown]
# ## 11.Task

# %%
#  Take a string and check if it is alphanumeric (isalnum()).

string = input("Enter the string:")

print(string.isalnum())
# Out:
# Enter the string: 12yas
# True

# %% [markdown]
# ## 12.Task

# %%
 # Take a string and check if it is completely in lowercase (islower()).

string = input("Enter the string:")

print("completely in lower case" * ( string.islower() == True) or "String is not completely in lower case")
# Out:
# Enter the string: yash
# completely in lower case

# %% [markdown]
# ## 13.task

# %%
"""Take a password as input and check:
• It should be alphanumeric
• It should be minimum 8 characters long Print "Valid Password" or
"Invalid Password"."""

string = input("Enter any string:")

print("valid password" * ( string.isalnum() == True and len(string) >= 8 ) or "Invalid Password")
# Out:
# Enter any number: yash1234
# valid password

# %% [markdown]
# # find() and index() Questions

# %% [markdown]
# ## 14.Task

# %%
# Take a string and a character from user. Find the first occurrence of
# that character using find().

string = input("Enter any string:")
char = input("Which character you want to find:")
print(f"First occurrence of character in {string.find(char)} index")
# Out:
# Enter any string: yash
# Which character you want to find: a
# First occurrence of character in 1 index

# %% [markdown]
# ## 15.Task

# %%
# Take a string and a word. Use find() to check if the word exists. If not found, print -1.
string = input("Enter any string:")
char = input("Which character you want to find in this string:")

print("exist" * (string.find(char) != -1) or "-1")
# Out:
# Enter any string: YashDeore
# Which character you want to find in this string: D
# exist

# %% [markdown]
# ## 16.Task

# %%
# Take a sentence and find the position of the word "Python" using index().
string = input("Enter any string:")
char = input("Which word possition you want to find:")

print(f"Possition of  this '{char}' character or word is {string.index(char) + 1 }")
# Out:
# Enter any string: yashDeore
# Which word possition you want to find: Deo
# Possition of  this 'Deo' character or word is 5

# %% [markdown]
# ## 17.Task

# %%
# Take a string. Use both find() and index() to search for a character
# that does not exist. Observe the difference.

string = input("Enter any string:")
char = input("Which characters possitioin you want to find:")

# using find() method

print(f"output using find() method :{string.find(char)}") # when we give the not existed character to find index it reterns -1

# using index() method

print(f"output using index() method : {string.index(char)}") # when we give the not existed character to find index it reters error
# Out:
# Enter any string: Yash Deore
# Which characters possitioin you want to find: d
# output using find() method :-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 13
#       9 print(f"output using find() method :{string.find(char)}")
#      11 # using index() method
# ---> 13 print(f"output using index() method : {string.index(char)}")
#
# ValueError: substring not found

# %% [markdown]
# ## Mixed Questions

# %% [markdown]
# ## 18.Task

# %%
"""Take your full name.
• Convert it to uppercase
• Find the position of first space
• Print the first name and last name separately."""

name = "Yash Bhalchandra Deore"

print("convert it in uppercase:",name.upper())

print("Position of the first space:",name.find(" "))

print(f"first name is '{name[ :4]}' and the last name is '{ name[-5: ]}'")
# Out:
# convert it in uppercase: YASH BHALCHANDRA DEORE
# Position of the first space: 4
# first name is 'Yash' and the last name is 'Deore'

# %% [markdown]
# ## 19.Task

# %%
# Take a mobile number as string. Check if it is 10 digits and contains
# only numbers using isdigit() and len().

string = input("Enter any sring:")

print("Length of number is:",len(string))

print("number is valid" * ( len(string) == 10 and string.isdigit() ) or "Invalid Number")
# Out:
# Enter any sring: 23535
# Length of number is: 5
# Invalid Number

# %% [markdown]
# ## 20.Task

# %%
"""20. Take any string from user.
• Print the string in reverse order using slicing
• Convert it to title case
• Check if the reversed string is same as original (Palindrome check)"""

string = input("Enter any string:")

print(f"original string is '{string}' and Reverseorder string is '{string[::-1]}'")
print("Title case:",string.title())

print("Palindrome string" * ( string[::-1] == string ) or " Not Palindrome string")
# Out:
# Enter any string: mom
# original string is 'mom' and Reverseorder string is 'mom'
# Title case: Mom
# Palindrome string

# %%
string = input("Enter the string:")

string = string.split(" ")

print("My name is:",string[0])
print("My surname is:",string[2])
# Out:
# Enter the string: Yash Bhalchandra Deore
# My name is: Yash
# My surname is: Deore

# %%
# take a three numbers and find gratter

num1 = input("Enter first number:")
num2 = input("Enter secound number:")
num3 = input("Enter third number:")

print(f"number {num1} is gratter" * ( num1 >= num2 and num1 >= num3) 
      or (f"number {num2} is gratter" * ( num2 >= num1 and num2 >= num3 )
      or f"number {num3} is gratter"))
# Out:
# Enter first number: 9
# Enter secound number: 4
# Enter third number: 93
# number 93 is gratter

# %%
number1 = float(input("Enter any number:"))
operator = input("Enter any arithmatic operator:")
number2 = float(input("Enter any number:"))

print(f"Addition is '{ number1 + number2}'" * ( operator == "+" ) or 
     (f"Sutraction is '{ number1 - number2}'" * ( operator == "-") or
     (f"Multiplication is '{ number1 * number2}'" * (operator == "*") or
     (f"Division is '{ number1 / number2 }'" * (operator == "/") or
     (f"Floor division is '{ number1 // number2 }'" * (operator == "//") or
     (f"Remainder is '{ number1 % number2 } '" * (operator == "%") or
     (f"Exponent is '{ number1 ** number2 }'" * (operator == "**") or " Invalid operator ")))))))
# Out:
# Enter any number: 2
# Enter any arithmatic operator: *
# Enter any number: 2
# Multiplication is '4.0'

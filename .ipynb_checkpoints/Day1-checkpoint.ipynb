# %%
print(" Hellow World ")
# Out:
#  Hellow World

# %% [markdown]
# #####Yash Deore

# %%
b = "Hello World"
print(b[1:4])
# Out:
# ell

# %%
A = 3
B = 5
A += B
print(A)
# Out:
# 8

# %%
A = 3
B = 5
A = A + B
A
# Out:
# 8

# %%
A+=B
A

# %%
A>B
# Out:
# True

# %%
A + B
# Out:
# 23

# %%
x = "yash"
y = " Rohit"
z = x + y
print(z)
# Out:
# yash Rohit

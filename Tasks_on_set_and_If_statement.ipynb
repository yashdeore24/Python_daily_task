# %% [markdown]
# # 1.Task

# %% [markdown]
# ### 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

# %%
Set =  {1, 2, 3, 2, 4, 1}
print(Set)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # 2.Task

# %% [markdown]
# ### 2. (Easy) Create an empty set using correct syntax and add 3 numbers using add().

# %%
Set = set()

Set.add(1)
Set.add(2)
Set.add(3)

Set
# Out:
# {1, 2, 3}

# %% [markdown]
# ### 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().

# %%
s = {10, 20, 30}
s.update([40,50,60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %% [markdown]
# ### 4. (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

# %%
s = {10, 20, 30, 40}
s.remove(20)
print(s)
s = {10, 20, 30, 40}
s.discard(20)
print(s)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %% [markdown]
# ### 5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
C = A.union(B)
print("Union operation:",C)
C = A.intersection(B)
print("Intersection:",C)
C = A.difference(B)
print("Difference:",C)
# Out:
# Union operation: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %% [markdown]
# ### 6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.

# %%
s = {10, 20, 30, 40}
print(25 in s)
# Out:
# False

# %% [markdown]
# ### 7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.

# %%
List = [1, 2, 2, 3, 4, 4, 5]
Set = set(List)
print("Lenth of set:",len(Set))
# Out:
# Lenth of set: 5

# %% [markdown]
# ### 8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.

# %%
no1 = int(input("Enter any number:"))
no2 = int(input("Enter any number:"))
no3 = int(input("Enter any number:"))
no4 = int(input("Enter any number:"))
no5 = int(input("Enter any number:"))

Set = {no1,no2,no3,no4,no5}
print(Set)
print(Set)
# Out:
# Enter any number: 1
# Enter any number: 2
# Enter any number: 1
# Enter any number: 3
# Enter any number: 2
# {1, 2, 3}
# {1, 2, 3}

# %% [markdown]
# ### 9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B

# %%
A = {1, 2, 3}
B = {3, 4, 5}

C = A.difference(B)
print(C)
# Out:
# {1, 2}

# %% [markdown]
# ### 10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?

# %%
A = {1, 2, 3}

A.add([3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 A = {1, 2, 3}
# ----> 3 A.add([3])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # If Statement Questions (11-20)

# %% [markdown]
# ### 11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".

# %%
Age = 22

if Age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %% [markdown]
# ### 12. (Easy) Take a number and check if it is positive, negative, or zero using if-elif-else.

# %%
number = int(input("Enter the number:"))

if  number > 0 :
    print("Positive")
elif number < 0:
    print("Negative")
else:
    print("Zore")

# %% [markdown]
# ### 13. (Medium) Take two numbers and print the larger one using if-else.

# %%
number = int(input("Enter any number:"))
Number = int(input("Enter any number:"))


if number > Number:
    print(F"{number } is gratterthan {Number}" )
else:
     print(F"{Number } is gratterthan {number} ")
# Out:
# Enter any number: 3
# Enter any number: 5
# 5 is gratterthan 3

# %% [markdown]
# ### 14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using if statement.

# %%
vowe = input("Enter any character:")

if vowe == 'a' or vowe == 'e' or vowe == 'i' or vowe == 'o' or vowe == 'u':
    print("Character is Vowel")

# %% [markdown]
# ### 15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else →Fail.

# %%
marks = float(input("Enter the marks:"))

if marks >=90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
else:
    print("Fail")
# Out:
# Enter the marks: 89
# B

# %% [markdown]
# ### 16. (Hard) Take three numbers and print the largest one using if-elif-else.

# %%
n1 = float(input("Enter any number:"))
n2 = float(input("Enter any number:"))
n3 = float(input("Enter any number:"))
           
if n1 >= n2 and n1 >= n3:
     print(f"{n1} is gratter")
elif n2 >= n1 and n2 >= n3:
    print(f"{n2} is gratter")
else:
    print(f"{n3} is gratter")
# Out:
# Enter any number: 2
# Enter any number: 1
# Enter any number: 4
# 4.0 is gratter

# %% [markdown]
# ### 17. (Hard) Take a number and check if it is even and greater than 50.

# %%
number = float(input("Enter the number:"))

if number % 2 == 0 and number > 50 :
    print("Number is even and greater than 50")
# Out:
# Enter the number: 55

# %% [markdown]
# ### 18. (Hard) Take username and password. If username == "admin" and password == "1234", print "Login Successful", else "Login Failed".

# %%
username = input("Enter username:")
password = input("Enter password:")

if username == "admin" and password == "1234":
    print("login succesful")
else:
    print("Login is fail")

# %% [markdown]
# ### 19. (Hard) Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).

# %%
year = int(input("Enter year:"))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("leap year:")
else:
    print("Not leap year")

# %% [markdown]
# ### 20.(Hard) Take three sides of a triangle and check if they can form a valid triangle
# (sum of any two sides > third side

# %%
side1 = float(input("Enter the first side:"))
side2 = float(input("Enter the secound side:"))
side3 = float(input("Enter the third side:"))

if side1 + side2 > side3:
    print("Valid triangle:")
else:
    print("not valid")
# Out:
# Enter the first side: 2
# Enter the secound side: 3
# Enter the third side: 4
# Valid triangle:

# %% [markdown]
# ### 21. Take three numbers as input from the user. Print the largest number and
# also check whether all three numbers are equal or not.

# %%
n1 = float(input("Enter any number:"))
n2 = float(input("Enter any number:"))
n3 = float(input("Enter any number:"))

if n1 == n2 and n2 == n3:
    print("All numbers are equal")
elif n1 >= n2 and n1 >= n3:
     print(f"{n1} is gratter")
elif n2 >= n1 and n2 >= n3:
    print(f"{n2} is gratter")
elif n3 >= no1 and no3 >= no2:
    print(f"{n3} is gratter")
else:
    print("All numbers are equal:")
# Out:
# Enter any number: 2
# Enter any number: 2
# Enter any number: 2
# All numbers are equal

# %% [markdown]
# ### 22. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)

# %%
year = int(input("Enter year:"))

if  (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("leap year:")
else:
    print("Not leap year")
# Out:
# Enter year: 2004
# Not leap year

# %% [markdown]
# ### 23. 3. (Hard) Take three sides of a triangle as input. Check if they can form a valid triangle (sum of any two sides must be greater than the third side). If valid, also print the type (Equilateral, Isosceles, or Scalene).

# %%
side1 = float(input("Enter the first side:"))
side2 = float(input("Enter the secound side:"))
side3 = float(input("Enter the third side:"))

if side1 + side2 > side3:
    print("isosceles Triangle:")
elif side1 == side2 and side2 == side3:
    print("Equilateral traiangle")
elif side1 != side2 and side2 != side3 and side1 != side3 :
    print("Scalene Triangle:")
else:
    print("not valid")
# Out:
# Enter the first side: 3
# Enter the secound side: 3
# Enter the third side: 3
# isosceles Triangle:

# %% [markdown]
# ### 24.Take a student's marks in 5 subjects. Calculate percentage and print gradeaccording to these rules:

# %%
             
marks1 = float(input("Enter marks:"))
marks2 = float(input("Enter marks:"))
marks3 = float(input("Enter marks:"))
marks4 = float(input("Enter marks:"))
marks5 = float(input("Enter marks:"))

total = marks1 + marks2 + marks3 + marks4 + marks5

per = total /500 * 100
print("Percentage:",per)

if per > 90:
    print("A+")
elif per > 80 and per < 90:
    print("A")
elif per > 70  and per < 80:
    print("B")
elif per > 60 and per < 70:
    print("C")
else:
    print("Fail")
# Out:
# Enter marks: 89
# Enter marks: 99
# Enter marks: 90
# Enter marks: 88
# Enter marks: 99
# Percentage: 93.0
# A+

# %% [markdown]
# ### 25. Take username, password, and age as input.
# ### • If username == "admin" and password == "python123" and age >= 18 → Print
# ### "Login Successful"
# ### • Else if age < 18 → Print "You are too young to login"
# ### Else → Print "Invalid Credentials"

# %%
username = input("Enter username:")
password = input("Enter password:")
age = int(input("Enter age:"))
if username == "admin" and password == "python123" and age >= 18:
    print("login succesful")
elif age < 18 :
    print("You are too young to login")
else:
    print("Login is fail")
# Out:
# Enter username: admin
# Enter password: python123
# Enter age: 12
# You are too young to login
